# %% [markdown]
# <a href="https://colab.research.google.com/github/likithay128298-afk/DAA-Lab/blob/main/Practical_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Implementation and time analysis of factorial program using iterative and recursive method

# %% [markdown]
# Using Iterative Method

# %%
n = int(input("Enter a number: "))

fact = 1

for i in range(1, n + 1):
    fact *= i

print("Factorial =", fact)
# Out:
# Enter a number: 5
# Factorial = 120

# %% [markdown]
# Using Recursive Method

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial(n - 1)

n = int(input("Enter a number: "))

print("Factorial =", factorial(n))
# Out:
# Enter a number: 6
# Factorial = 720
