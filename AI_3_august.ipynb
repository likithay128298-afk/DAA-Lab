# %% [markdown]
# <a href="https://colab.research.google.com/github/likithay128298-afk/DAA-Lab/blob/main/AI_3_august.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
spam_keywords = ["lottery","win","prize","money","won"]
email = input("Enter an email.\n")
is_spam = False
for word in spam_keywords:
    if word in email:
      is_spam = True
      break[5]:
if is_spam:
 print("Mail is spam")
else:
 print("Mail is not spam")
# Out:
#   File "/tmp/ipykernel_648/1833134586.py", line 8
#     break[5]:
#          ^
# SyntaxError: invalid syntax
