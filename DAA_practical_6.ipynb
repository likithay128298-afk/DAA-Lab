# %% [markdown]
# <a href="https://colab.research.google.com/github/likithay128298-afk/DAA-Lab/blob/main/DAA_practical_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def matrix_chain_order(p):
    n = len(p) - 1

    # dp[i][j] stores minimum multiplication cost
    dp = [[0 for _ in range(n + 1)] for _ in range(n + 1)]

    # length is the chain length
    for length in range(2, n + 1):
        for i in range(1, n - length + 2):
            j = i + length - 1
            dp[i][j] = float('inf')

            # Try every possible split
            for k in range(i, j):
                cost = (
                    dp[i][k]
                    + dp[k + 1][j]
                    + p[i - 1] * p[k] * p[j]
                )

                dp[i][j] = min(dp[i][j], cost)

    return dp[1][n]


# Main program
n = int(input("Enter number of matrices: "))

print("Enter matrix dimensions:")

p = []

for i in range(n):
    rows = int(input(f"Enter rows of Matrix {i + 1}: "))

    if i == 0:
        p.append(rows)

    cols = int(input(f"Enter columns of Matrix {i + 1}: "))
    p.append(cols)

# Calculate minimum cost
minimum_cost = matrix_chain_order(p)

print("\nMinimum number of scalar multiplications:",
      minimum_cost)
# Out:
# Enter number of matrices: 3
# Enter matrix dimensions:
# Enter rows of Matrix 1: 5
# Enter columns of Matrix 1: 5
# Enter rows of Matrix 2: 5
# Enter columns of Matrix 2: 5
# Enter rows of Matrix 3: 5
# Enter columns of Matrix 3: 5
#
# Minimum number of scalar multiplications: 250
